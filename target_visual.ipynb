# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('target_train.csv')
df
# Out:
#            ID  OS_YEARS  OS_STATUS
# 0     P132697  1.115068        1.0
# 1     P132698  4.928767        0.0
# 2     P116889  2.043836        0.0
# 3     P132699  2.476712        1.0
# 4     P132700  3.145205        0.0
# ...       ...       ...        ...
# 3318  P121828       NaN        NaN
# 3319  P121829       NaN        NaN
# 3320  P121830  1.997260        0.0
# 3321  P121853  0.095890        1.0
# 3322  P121834  2.290411        0.0
#
# [3323 rows x 3 columns]

# %%
plt.figure(figsize=(15, 5))
plt.title("Histogram of survival years of patients")
plt.hist(df['OS_YEARS'], bins=30)
plt.grid()
plt.xlabel('Years')
plt.ylabel('Count')
plt.show()
